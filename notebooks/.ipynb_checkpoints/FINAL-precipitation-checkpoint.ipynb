# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import seaborn as sns
import scipy as sp
import datetime as dt
import scipy
import calendar

# %%
imgFolder = pathlib.Path(r'G:\Meu Drive\USP-Mestrado\Masters-Data\Imgs\Final')

# %%
precip = pd.read_csv(r"G:\Meu Drive\USP-Mestrado\Masters-Data\norm.csv", encoding='latin', delimiter=';')

# %%
precip['Month_n'] = precip['Month'].apply(lambda x: calendar.month_abbr[x])

# %%
precip = precip.rename(columns=({'Rainfall (mm)':'Rainfall [mm]',
                                 'Temperature (°C)': 'Temperature [°C]'}))

# %%
precip
# Out:
#     Month  Rainfall [mm]  Temperature [°C] Month_n
# 0       1          286.4              22.4     Jan
# 1       2          222.2              23.1     Feb
# 2       3          171.5              22.4     Mar
# 3       4           82.0              21.1     Apr
# 4       5           60.6              18.1     May
# 5       6           36.2              17.3     Jun
# 6       7           28.1              17.2     Jul
# 7       8           24.5              18.9     Aug
# 8       9           66.8              20.8     Sep
# 9      10          120.1              22.1     Oct
# 10     11          157.5              22.3     Nov
# 11     12          226.2              22.7     Dec

# %%
# sns.set_theme(style="darkgrid")
# sns.set_style("white")
sns.set_style("darkgrid")

fig, ax = plt.subplots(1, figsize=(6,3), dpi=300)

ax2 = plt.twinx()

sns.barplot(data=precip, x='Month_n', y='Rainfall [mm]', color='#3337b0',ax=ax)

sns.lineplot(data=precip, x='Month_n', y='Temperature [°C]', color='#bd2d32',ax=ax2)
ax2.grid(False)
ax2.set_ylim((0,25))
# sns.despine(ax=ax2)
ax.set_xlabel('')

# fig.savefig(imgFolder/'precip_temp.png')
